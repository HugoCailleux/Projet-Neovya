# %%
import os
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from datetime import date, datetime
import time

# %% [markdown]
# ## Etapes:
#
# - sélection des capteurs qui correspondent à nos critères : colonnes speed non vide + enregistrement toutes les six minutes
# - Suppression des colonnes inutiles ou pas assez fournies ('VL/h', 'PL/h', 'Unnamed: 0', 'delta', 'occupancy')
# - Ajout des données météos
# - Add Datepart
# - Création d'une carte avec les capteurs (non-utilisées)
# - Ajout des variables à prédire

# %% [markdown]
# ## Sélection des capteurs

# %%
df_n230 = pd.read_csv('data/df_n230_clean.csv')

# %%
df_n230 = df_n230[df_n230['date'] > '2019-09-23']

# %%
len(df_n230['sensor'].value_counts())
# Out:
# 65

# %%
df_n230['sensor'].value_counts().head(35)
# Out:
# 5044.14 2    6720
# 5044.12 2    6720
# 5146.11 1    6720
# 5442.20 2    6720
# 5146.12 2    6720
# 5742.00 2    6720
# 5146.10 2    6720
# 5143.10 2    6720
# 5442.21 2    6720
# 5044.01 2    6720
# 5143.00 2    6720
# LAPI L42     6720
# 5442.00 2    6720
# 5043.00 1    6720
# 5044.10 2    6720
# 5143.01 1    6720
# 5143.11 1    6720
# 5044.15 1    6720
# 5143.01 2    6720
# 5043.21 2    6720
# 5043.20 2    6720
# 5044.11 1    6720
# 5044.13 1    6720
# 5342.10 1    6720
# 5146.13 1    6720
# LAPI L41     6720
# 5043.15 1    6720
# 5146.14 2    6720
# 5342.00 1    6720
# 5042.00 2    6720
# 5342.11 1    6720
# 5143.12 2    6720
# 5146.15 1    6720
# 5042.00 1    6720
# 5044.01 1    6720
# Name: sensor, dtype: int64

# %%
df_n230['sensor'].value_counts().tail(30)
# Out:
# 5143.13 1      6720
# 5742.00 1      6720
# S_MBG33.V_0     889
# S_MB333.e_0     889
# S_MB333.e_1     889
# S_MBG33.M_0     889
# S_MB233.V_0     889
# S_MBG33.M_5     889
# S_MB333.D_1     889
# S_MBG33.T_1     889
# S_MBG33.T_0     889
# S_MBG33.n_0     889
# S_MBG33.V_1     889
# S_MB333.D_0     889
# S_MB333.e_6     889
# S_MBG33.M_3     889
# S_MB233.V_1     889
# S_MBG33.n_1     889
# S_MB333.e_4     889
# S_MBG33.N_0     889
# S_MB333.M_1     889
# S_MBG33.M_4     889
# S_MB333.e_2     889
# S_MB333.M_0     889
# S_MBG33.R_0     889
# S_MBG33.M_1     889
# S_MBG33.R_1     889
# S_MBG33.M_2     889
# S_MB333.e_5     889
# S_MBG33.N_1     888
# Name: sensor, dtype: int64

# %% [markdown]
# ## Supprimons les capteurs qui n'ont pas des enregistrements toutes les six minutes

# %%
delta = df_n230['delta'][df_n230['sensor'] == 'LAPI L42'].value_counts().index[0]

# %%
sensor_to_remove_delta = []
for k in range(len(df_n230['sensor'].value_counts())):
    capteur = df_n230['sensor'].value_counts().index[k]
    df = df_n230[df_n230['sensor'] == capteur]
    delta_capteur = df['delta'].value_counts().index[0]
    #print(capteur)
    #print(df['delta'].value_counts().index[0])
    if delta_capteur != delta:
        sensor_to_remove_delta.append(capteur)
print(len(sensor_to_remove_delta))
# Out:
# 28

# %% [markdown]
# ## Supprimons les capteurs qui n'ont pas de données pour la colonne speed

# %%
len(df_n230['sensor'].value_counts())
df = df_n230[df_n230['sensor'] == df_n230['sensor'].value_counts(dropna=False).index[k]]

# %%
sensor_to_remove_speed = []
for k in range(len(df_n230['sensor'].value_counts())): 
    df = df_n230[df_n230['sensor'] == df_n230['sensor'].value_counts(dropna=False).index[k]]
    if len(df['speed'].value_counts(dropna = False)) == 1:
        sensor_to_remove_speed.append(df_n230['sensor'].value_counts().index[k])
print(len(sensor_to_remove_speed))
# Out:
# 41

# %%
for index, sensor in enumerate(sensor_to_remove_speed):
    if sensor in sensor_to_remove_delta:
        sensor_to_remove_speed.pop(index)
sensor_to_remove = sensor_to_remove_speed + sensor_to_remove_delta
print(len(sensor_to_remove))
# Out:
# 55

# %%
dirty_idx = []
for sensor in sensor_to_remove:
    df = df_n230[df_n230['sensor'] == sensor]
    for i in range(len(df)):
        dirty_idx.append(df.index[i])
print(len(dirty_idx))
# Out:
# 124696

# %%
df_n230 = df_n230[~df_n230.index.isin(dirty_idx)]

# %% [markdown]
# Vérifions:

# %%
capteurs_restants = df_n230['sensor'].value_counts().index.tolist()
for capteur in capteurs_restants:
    speed_values = df_n230['speed'][df_n230['sensor'] == capteur].value_counts(dropna=False)
    print(capteur,':')
    print(speed_values)
    print('  ')
# Out:
# 5146.11 1 :
# 76.0    580
# 75.0    528
# 77.0    511
# 74.0    460
# 78.0    451
#        ...
# 34.0      1
# 13.0      1
# 9.0       1
# 47.0      1
# 15.0      1
# Name: speed, Length: 77, dtype: int64
#
# 5146.12 2 :
# 84.0     879
# 85.0     801
# 83.0     761
# 86.0     686
# 82.0     618
#         ...
# 102.0      1
# 26.0       1
# 99.0       1
# 103.0      1
# 36.0       1
# Name: speed, Length: 102, dtype: int64
#
# 5044.11 1 :
# 56.0    801
# 55.0    750
# 57.0    710
# 54.0    568
# 58.0    505
#        ...
# 72.0      1
# 8.0       1
# 5.0       1
# 68.0      1
# NaN       1
# Name: speed, Length: 62, dtype: int64
#
# 5143.01 2 :
# 87.0    1268
# 88.0    1230
# 86.0    1071
# 89.0     907
# 85.0     593
#         ...
# 69.0       1
# 10.0       1
# 22.0       1
# 13.0       1
# 37.0       1
# Name: speed, Length: 83, dtype: int64
#
# 5044.12 2 :
# 43.0    1052
# 44.0     995
# 42.0     931
# 41.0     777
# 45.0     731
# 40.0     524
# 46.0     503
# 39.0     305
# 47.0     270
# 38.0     170
# 48.0     139
# 37.0      88
# 49.0      56
# 36.0      43
# 50.0      24
# 35.0      16
# 34.0      14
# 51.0      14
# 52.0      10
# 33.0       6
# 30.0       5
# 31.0       4
# 54.0       4
# 22.0       3
# NaN        3
# 15.0       3
# 0.0        3
# 19.0       2
# 53.0       2
# 55.0       2
# 27.0       2
# 9.0        2
# 21.0       2
# 18.0       1
# 56.0       1
# 6.0        1
# 23.0       1
# 58.0       1
# 10.0       1
# 60.0       1
# 26.0       1
# 20.0       1
# 11.0       1
# 17.0       1
# 25.0       1
# 13.0       1
# 12.0       1
# 32.0       1
# Name: speed, dtype: int64
#
# LAPI L41 :
# 89.0     1012
# 90.0      971
# 88.0      845
# 91.0      783
# 87.0      601
#          ...
# 7.0         1
# 10.0        1
# 108.0       1
# 5.0         1
# 118.0       1
# Name: speed, Length: 106, dtype: int64
#
# 5742.00 1 :
# 83.0    825
# 82.0    805
# 84.0    793
# 81.0    714
# 85.0    671
#        ...
# 10.0      1
# 93.0      1
# 7.0       1
# 17.0      1
# 9.0       1
# Name: speed, Length: 87, dtype: int64
#
# 5044.15 1 :
# 62.0     678
# 61.0     628
# 60.0     593
# 63.0     584
# 64.0     570
#         ...
# 88.0       1
# 119.0      1
# 92.0       1
# 120.0      1
# 93.0       1
# Name: speed, Length: 107, dtype: int64
#
# 5143.01 1 :
# 89.0    1191
# 88.0    1075
# 87.0     960
# 90.0     959
# 86.0     491
#         ...
# 75.0       4
# 66.0       4
# 11.0       3
# 10.0       1
# 12.0       1
# Name: speed, Length: 87, dtype: int64
#
# 5044.10 2 :
# 64.0    664
# 65.0    618
# 63.0    608
# 66.0    555
# 62.0    518
#        ...
# 80.0      1
# 82.0      1
# NaN       1
# 79.0      1
# 83.0      1
# Name: speed, Length: 74, dtype: int64
#
# 5043.00 1 :
# 90.0    998
# 89.0    908
# 91.0    768
# 88.0    631
# 87.0    490
#        ...
# 97.0      3
# 98.0      2
# 10.0      1
# 99.0      1
# 11.0      1
# Name: speed, Length: 91, dtype: int64
#
# 5146.15 1 :
# 61.0    721
# 60.0    684
# 62.0    583
# 59.0    577
# 58.0    526
#        ...
# 18.0      1
# 82.0      1
# 96.0      1
# 78.0      1
# 86.0      1
# Name: speed, Length: 67, dtype: int64
#
# 5442.00 2 :
# 86.0    991
# 87.0    965
# 85.0    835
# 88.0    667
# 84.0    620
#        ...
# 92.0      3
# 5.0       3
# 94.0      1
# 99.0      1
# 95.0      1
# Name: speed, Length: 93, dtype: int64
#
# LAPI L42 :
# 85.0    976
# 86.0    881
# 84.0    849
# 87.0    743
# 83.0    699
#        ...
# 6.0       4
# 92.0      3
# 93.0      1
# 96.0      1
# 94.0      1
# Name: speed, Length: 90, dtype: int64
#
# 5042.00 1 :
# 87.0    1663
# 86.0    1414
# 88.0    1163
# 85.0     684
# 89.0     630
#         ...
# 63.0       1
# 13.0       1
# 12.0       1
# 76.0       1
# 69.0       1
# Name: speed, Length: 85, dtype: int64
#
# 5143.00 2 :
# 86.0    977
# 85.0    834
# 87.0    751
# 84.0    629
# 83.0    540
#        ...
# 93.0      1
# 18.0      1
# 15.0      1
# 14.0      1
# 19.0      1
# Name: speed, Length: 80, dtype: int64
#
# 5044.01 2 :
# 86.0    998
# 87.0    909
# 85.0    868
# 84.0    803
# 88.0    672
# 83.0    669
# 82.0    454
# 89.0    351
# 81.0    290
# 80.0    210
# 90.0    122
# 79.0    113
# 78.0     65
# 91.0     44
# 77.0     39
# 76.0     23
# 75.0     15
# 92.0      6
# 74.0      5
# 54.0      4
# 94.0      4
# 73.0      4
# 49.0      3
# 35.0      3
# 39.0      3
# 72.0      3
# 34.0      2
# 55.0      2
# 56.0      2
# 32.0      2
# 40.0      2
# 18.0      2
# 68.0      2
# 26.0      2
# 51.0      1
# 19.0      1
# 24.0      1
# 36.0      1
# 14.0      1
# 38.0      1
# 43.0      1
# 67.0      1
# 46.0      1
# 48.0      1
# 20.0      1
# 61.0      1
# 42.0      1
# 28.0      1
# 29.0      1
# 59.0      1
# 27.0      1
# 22.0      1
# 93.0      1
# 45.0      1
# 66.0      1
# 33.0      1
# 70.0      1
# NaN       1
# Name: speed, dtype: int64
#
# 5042.00 2 :
# 86.0    944
# 87.0    886
# 85.0    878
# 84.0    680
# 88.0    672
#        ...
# 59.0      3
# 6.0       2
# 71.0      2
# 64.0      2
# 99.0      1
# Name: speed, Length: 91, dtype: int64
#
# 5146.10 2 :
# 79.0    776
# 80.0    753
# NaN     726
# 78.0    716
# 77.0    599
#        ...
# 8.0       1
# 49.0      1
# 9.0       1
# 56.0      1
# 99.0      1
# Name: speed, Length: 86, dtype: int64
#
# 5342.00 1 :
# 88.0    2074
# 89.0    1439
# 87.0    1230
# 90.0     636
# 86.0     511
#         ...
# 7.0        1
# 75.0       1
# 55.0       1
# 9.0        1
# 94.0       1
# Name: speed, Length: 87, dtype: int64
#
# 5146.14 2 :
# 50.0    1239
# 49.0    1051
# 51.0    1040
# 52.0     707
# 48.0     648
# 47.0     426
# 53.0     387
# 46.0     216
# 54.0     183
# 45.0     100
# 44.0      83
# 55.0      71
# 43.0      64
# 56.0      51
# 42.0      51
# 41.0      49
# 39.0      38
# 40.0      32
# 37.0      30
# 38.0      28
# 58.0      24
# 57.0      21
# NaN       19
# 0.0       19
# 35.0      18
# 34.0      15
# 36.0      15
# 59.0      13
# 33.0       9
# 60.0       7
# 29.0       7
# 28.0       7
# 23.0       6
# 32.0       6
# 63.0       5
# 62.0       5
# 22.0       4
# 27.0       3
# 25.0       3
# 24.0       3
# 31.0       3
# 26.0       3
# 61.0       2
# 20.0       2
# 66.0       2
# 17.0       1
# 64.0       1
# 69.0       1
# 65.0       1
# 30.0       1
# Name: speed, dtype: int64
#
# 5742.00 2 :
# 89.0     989
# 90.0     967
# 91.0     867
# 88.0     792
# 92.0     583
#         ...
# 6.0        1
# 102.0      1
# 64.0       1
# 74.0       1
# 8.0        1
# Name: speed, Length: 97, dtype: int64
#
# 5146.13 1 :
# 67.0    880
# 66.0    869
# 68.0    806
# 65.0    632
# 69.0    589
#        ...
# 44.0      1
# 47.0      1
# 49.0      1
# 34.0      1
# 83.0      1
# Name: speed, Length: 78, dtype: int64
#
# 5044.01 1 :
# 86.0    1090
# 87.0    1016
# 85.0     975
# 84.0     705
# 88.0     607
#         ...
# 40.0       2
# 8.0        2
# 95.0       2
# 98.0       1
# NaN        1
# Name: speed, Length: 89, dtype: int64

# %% [markdown]
# A priori tous les capteurs ont bien des données différentes pour la colonne speed. Vérifions le delta :

# %%
capteurs_restants = df_n230['sensor'].value_counts().index.tolist()
for capteur in capteurs_restants:
    speed_values = df_n230['delta'][df_n230['sensor'] == capteur].value_counts(dropna=False)
    print(capteur,':')
    print(speed_values)
    print('  ')
# Out:
# 5146.11 1 :
# 0 days 00:06:00       6719
# -28 days +00:06:00       1
# Name: delta, dtype: int64
#
# 5146.12 2 :
# 0 days 00:06:00       6719
# -28 days +00:06:00       1
# Name: delta, dtype: int64
#
# 5044.11 1 :
# 0 days 00:06:00       6719
# -28 days +00:06:00       1
# Name: delta, dtype: int64
#
# 5143.01 2 :
# 0 days 00:06:00       6719
# -28 days +00:06:00       1
# Name: delta, dtype: int64
#
# 5044.12 2 :
# 0 days 00:06:00       6719
# -28 days +00:06:00       1
# Name: delta, dtype: int64
#
# LAPI L41 :
# 0 days 00:06:00    6720
# Name: delta, dtype: int64
#
# 5742.00 1 :
# 0 days 00:06:00       6719
# -28 days +00:06:00       1
# Name: delta, dtype: int64
#
# 5044.15 1 :
# 0 days 00:06:00       6719
# -28 days +00:06:00       1
# Name: delta, dtype: int64
#
# 5143.01 1 :
# 0 days 00:06:00       6719
# -28 days +00:06:00       1
# Name: delta, dtype: int64
#
# 5044.10 2 :
# 0 days 00:06:00       6719
# -28 days +00:06:00       1
# Name: delta, dtype: int64
#
# 5043.00 1 :
# 0 days 00:06:00       6719
# -28 days +00:06:00       1
# Name: delta, dtype: int64
#
# 5146.15 1 :
# 0 days 00:06:00       6719
# -28 days +00:06:00       1
# Name: delta, dtype: int64
#
# 5442.00 2 :
# 0 days 00:06:00       6719
# -28 days +00:06:00       1
# Name: delta, dtype: int64
#
# LAPI L42 :
# 0 days 00:06:00    6720
# Name: delta, dtype: int64
#
# 5042.00 1 :
# 0 days 00:06:00       6719
# -28 days +00:06:00       1
# Name: delta, dtype: int64
#
# 5143.00 2 :
# 0 days 00:06:00       6719
# -28 days +00:06:00       1
# Name: delta, dtype: int64
#
# 5044.01 2 :
# 0 days 00:06:00       6719
# -28 days +00:06:00       1
# Name: delta, dtype: int64
#
# 5042.00 2 :
# 0 days 00:06:00       6719
# -28 days +00:06:00       1
# Name: delta, dtype: int64
#
# 5146.10 2 :
# 0 days 00:06:00       6719
# -28 days +00:06:00       1
# Name: delta, dtype: int64
#
# 5342.00 1 :
# 0 days 00:06:00       6719
# -28 days +00:06:00       1
# Name: delta, dtype: int64
#
# 5146.14 2 :
# 0 days 00:06:00       6719
# -28 days +00:06:00       1
# Name: delta, dtype: int64
#
# 5742.00 2 :
# 0 days 00:06:00       6719
# -28 days +00:06:00       1
# Name: delta, dtype: int64
#
# 5146.13 1 :
# 0 days 00:06:00       6719
# -28 days +00:06:00       1
# Name: delta, dtype: int64
#
# 5044.01 1 :
# 0 days 00:06:00       6719
# -28 days +00:06:00       1
# Name: delta, dtype: int64

# %%
anomalie = speed_values.index.tolist()[1]

# %%
df_n230[df_n230['delta'] == anomalie]
# Out:
#         Unnamed: 0     sensor                 date  VL/h  PL/h   TV/h  speed  \
# 53087        82919  5442.00 2  2019-09-23 00:00:00   NaN   NaN    NaN    NaN
# 66527        96359  5342.00 1  2019-09-23 00:00:00   NaN   NaN    NaN    NaN
# 79967       109799  5042.00 1  2019-09-23 00:00:00   NaN   NaN  510.0   89.0
# 86687       116519  5042.00 2  2019-09-23 00:00:00   NaN   NaN  620.0   87.0
# 93407       123239  5742.00 1  2019-09-23 00:00:00   NaN   NaN    NaN    NaN
# 100127      129959  5742.00 2  2019-09-23 00:00:00   NaN   NaN    NaN    NaN
# 127007      156839  5143.00 2  2019-09-23 00:00:00   NaN   NaN    NaN    NaN
# 147167      176999  5143.01 1  2019-09-23 00:00:00   NaN   NaN    NaN    NaN
# 153887      183719  5143.01 2  2019-09-23 00:00:00   NaN   NaN    NaN    NaN
# 174047      203879  5043.00 1  2019-09-23 00:00:00   NaN   NaN    NaN    NaN
# 180767      210599  5044.11 1  2019-09-23 00:00:00   NaN   NaN  160.0   57.0
# 194207      224039  5044.15 1  2019-09-23 00:00:00   NaN   NaN   90.0   60.0
# 200927      230759  5044.01 1  2019-09-23 00:00:00   NaN   NaN  590.0   88.0
# 207647      237479  5044.01 2  2019-09-23 00:00:00   NaN   NaN  670.0   88.0
# 214367      244199  5044.12 2  2019-09-23 00:00:00   NaN   NaN   90.0   47.0
# 221087      250919  5044.10 2  2019-09-23 00:00:00   NaN   NaN  190.0   64.0
# 234527      264359  5146.14 2  2019-09-23 00:00:00   NaN   NaN    NaN    NaN
# 241247      271079  5146.15 1  2019-09-23 00:00:00   NaN   NaN    NaN    NaN
# 247967      277799  5146.13 1  2019-09-23 00:00:00   NaN   NaN    NaN    NaN
# 254687      284519  5146.11 1  2019-09-23 00:00:00   NaN   NaN    NaN    NaN
# 261407      291239  5146.10 2  2019-09-23 00:00:00   NaN   NaN    NaN    NaN
# 268127      297959  5146.12 2  2019-09-23 00:00:00   NaN   NaN    NaN    NaN
#
#         occupancy               delta
# 53087         NaN  -28 days +00:06:00
# 66527         NaN  -28 days +00:06:00
# 79967         NaN  -28 days +00:06:00
# 86687         NaN  -28 days +00:06:00
# 93407         NaN  -28 days +00:06:00
# 100127        NaN  -28 days +00:06:00
# 127007        NaN  -28 days +00:06:00
# 147167        NaN  -28 days +00:06:00
# 153887        NaN  -28 days +00:06:00
# 174047        NaN  -28 days +00:06:00
# 180767        NaN  -28 days +00:06:00
# 194207        NaN  -28 days +00:06:00
# 200927        NaN  -28 days +00:06:00
# 207647        NaN  -28 days +00:06:00
# 214367        NaN  -28 days +00:06:00
# 221087        NaN  -28 days +00:06:00
# 234527        NaN  -28 days +00:06:00
# 241247        NaN  -28 days +00:06:00
# 247967        NaN  -28 days +00:06:00
# 254687        NaN  -28 days +00:06:00
# 261407        NaN  -28 days +00:06:00
# 268127        NaN  -28 days +00:06:00

# %%
capteurs_restants = df_n230['sensor'].value_counts().index.tolist()
for capteur in capteurs_restants:
    speed_values = df_n230['TV/h'][df_n230['sensor'] == capteur].value_counts(dropna=False)
    print(capteur,':')
    print(speed_values)
    print('  ')
# Out:
# 5146.11 1 :
# NaN       199
# 240.0      83
# 270.0      74
# 260.0      71
# 230.0      67
#          ...
# 3170.0      1
# 3440.0      1
# 3180.0      1
# 3220.0      1
# 3000.0      1
# Name: TV/h, Length: 323, dtype: int64
#
# 5146.12 2 :
# 300.0     58
# 330.0     57
# 310.0     56
# 240.0     54
# 320.0     54
#           ..
# 2960.0     1
# 2800.0     1
# 3210.0     1
# 3030.0     1
# 2830.0     1
# Name: TV/h, Length: 310, dtype: int64
#
# 5044.11 1 :
# 90.0      127
# 80.0      123
# 120.0     121
# 110.0     120
# 70.0      112
#          ...
# 1610.0      1
# 1570.0      1
# 1490.0      1
# 1650.0      1
# NaN         1
# Name: TV/h, Length: 160, dtype: int64
#
# 5143.01 2 :
# 330.0     54
# 360.0     51
# 500.0     47
# 380.0     43
# 340.0     40
#           ..
# 5340.0     1
# 5140.0     1
# 4910.0     1
# 5050.0     1
# 5220.0     1
# Name: TV/h, Length: 503, dtype: int64
#
# 5044.12 2 :
# 60.0      148
# 90.0      147
# 70.0      144
# 80.0      132
# 40.0      129
#          ...
# 0.0         3
# 1460.0      2
# 1510.0      2
# 1540.0      1
# 1520.0      1
# Name: TV/h, Length: 154, dtype: int64
#
# LAPI L41 :
# 360.0     47
# 380.0     46
# 340.0     46
# 280.0     46
# 300.0     43
#           ..
# 5190.0     1
# 5570.0     1
# 5500.0     1
# 5460.0     1
# 5710.0     1
# Name: TV/h, Length: 554, dtype: int64
#
# 5742.00 1 :
# 330.0     56
# 380.0     47
# 300.0     46
# 350.0     46
# 340.0     46
#           ..
# 5810.0     1
# 5740.0     1
# 5520.0     1
# 150.0      1
# 5380.0     1
# Name: TV/h, Length: 554, dtype: int64
#
# 5044.15 1 :
# 60.0      166
# 50.0      142
# 80.0      139
# 70.0      135
# 90.0      117
#          ...
# 1720.0      1
# 1670.0      1
# 1620.0      1
# 1800.0      1
# 1510.0      1
# Name: TV/h, Length: 167, dtype: int64
#
# 5143.01 1 :
# 340.0     63
# 540.0     55
# 430.0     51
# 330.0     48
# 390.0     47
#           ..
# 5370.0     1
# 5050.0     1
# 5290.0     1
# 5150.0     1
# 5170.0     1
# Name: TV/h, Length: 510, dtype: int64
#
# 5044.10 2 :
# 90.0      133
# 80.0      115
# 100.0     110
# 120.0     106
# 110.0     101
#          ...
# 1640.0      1
# 1670.0      1
# 1710.0      1
# 1700.0      1
# 1650.0      1
# Name: TV/h, Length: 170, dtype: int64
#
# 5043.00 1 :
# 350.0     56
# 410.0     49
# 360.0     48
# 340.0     45
# 320.0     45
#           ..
# 5520.0     1
# 5160.0     1
# 5170.0     1
# 5460.0     1
# 170.0      1
# Name: TV/h, Length: 538, dtype: int64
#
# 5146.15 1 :
# 30.0     262
# 50.0     254
# 20.0     249
# 40.0     232
# 60.0     185
#         ...
# 780.0      1
# 820.0      1
# 880.0      1
# 890.0      1
# 810.0      1
# Name: TV/h, Length: 81, dtype: int64
#
# 5442.00 2 :
# 420.0     54
# 380.0     47
# 440.0     46
# 360.0     46
# 400.0     45
#           ..
# 5010.0     1
# 4470.0     1
# 5260.0     1
# 4890.0     1
# 4710.0     1
# Name: TV/h, Length: 487, dtype: int64
#
# LAPI L42 :
# 350.0     47
# 360.0     46
# 390.0     44
# 400.0     44
# 330.0     42
#           ..
# 5170.0     1
# 5090.0     1
# 5460.0     1
# 4470.0     1
# 5240.0     1
# Name: TV/h, Length: 514, dtype: int64
#
# 5042.00 1 :
# 380.0     52
# 310.0     51
# 340.0     50
# 330.0     48
# 360.0     46
#           ..
# 5540.0     1
# 150.0      1
# 5630.0     1
# 5530.0     1
# 110.0      1
# Name: TV/h, Length: 554, dtype: int64
#
# 5143.00 2 :
# 430.0     48
# 390.0     45
# 370.0     45
# 380.0     44
# 330.0     44
#           ..
# 5600.0     1
# 5720.0     1
# 5640.0     1
# 5390.0     1
# 5560.0     1
# Name: TV/h, Length: 546, dtype: int64
#
# 5044.01 2 :
# 330.0     61
# 380.0     59
# 280.0     59
# 370.0     52
# 460.0     50
#           ..
# 1160.0     1
# 4290.0     1
# 4180.0     1
# 90.0       1
# NaN        1
# Name: TV/h, Length: 421, dtype: int64
#
# 5042.00 2 :
# 410.0     48
# 390.0     47
# 340.0     45
# 400.0     44
# 440.0     43
#           ..
# 4970.0     1
# 70.0       1
# 5030.0     1
# 120.0      1
# 5310.0     1
# Name: TV/h, Length: 524, dtype: int64
#
# 5146.10 2 :
# NaN       726
# 120.0      75
# 100.0      64
# 80.0       62
# 140.0      58
#          ...
# 2920.0      1
# 3080.0      1
# 2930.0      1
# 2850.0      1
# 2800.0      1
# Name: TV/h, Length: 288, dtype: int64
#
# 5342.00 1 :
# 350.0     56
# 310.0     52
# 340.0     52
# 330.0     49
# 300.0     46
#           ..
# 5170.0     1
# 5210.0     1
# 5200.0     1
# 5120.0     1
# 4800.0     1
# Name: TV/h, Length: 510, dtype: int64
#
# 5146.14 2 :
# 30.0      179
# 450.0     152
# 50.0      149
# 40.0      148
# 430.0     144
#          ...
# 1220.0      1
# 1300.0      1
# 1150.0      1
# 1380.0      1
# 1050.0      1
# Name: TV/h, Length: 121, dtype: int64
#
# 5742.00 2 :
# 460.0     51
# 320.0     47
# 480.0     46
# 400.0     46
# 420.0     42
#           ..
# 5190.0     1
# 5460.0     1
# 5710.0     1
# 5260.0     1
# 5240.0     1
# Name: TV/h, Length: 530, dtype: int64
#
# 5146.13 1 :
# 110.0     84
# 100.0     83
# 70.0      79
# 130.0     73
# 60.0      73
#           ..
# 2620.0     1
# 2750.0     1
# 2580.0     1
# 2600.0     1
# 2560.0     1
# Name: TV/h, Length: 271, dtype: int64
#
# 5044.01 1 :
# 280.0     70
# 320.0     57
# 290.0     54
# 330.0     51
# 300.0     51
#           ..
# 4770.0     1
# 4320.0     1
# 120.0      1
# 4370.0     1
# NaN        1
# Name: TV/h, Length: 438, dtype: int64

# %% [markdown]
# Hormis les capteurs LAPIL, les colonnes PL/h et VL/h sont toujours vides. Supprimons les ainsi que les colonnes que nous n'utiliserons pas : Occupancy, Delta, Unnamed: 0

# %%
df_n230.drop(['VL/h', 'PL/h', 'Unnamed: 0', 'delta', 'occupancy'], axis = 1, inplace = True)

# %%
df_n230
# Out:
#            sensor                 date   TV/h  speed
# 53087   5442.00 2  2019-09-23 00:00:00    NaN    NaN
# 53088   5442.00 2  2019-09-23 00:06:00    NaN    NaN
# 53089   5442.00 2  2019-09-23 00:12:00  490.0   88.0
# 53090   5442.00 2  2019-09-23 00:18:00  470.0   89.0
# 53091   5442.00 2  2019-09-23 00:24:00  420.0   86.0
# ...           ...                  ...    ...    ...
# 289242   LAPI L42  2019-10-20 23:30:00  520.0   88.0
# 289243   LAPI L42  2019-10-20 23:36:00  690.0   85.0
# 289244   LAPI L42  2019-10-20 23:42:00  590.0   90.0
# 289245   LAPI L42  2019-10-20 23:48:00  510.0   86.0
# 289246   LAPI L42  2019-10-20 23:54:00  650.0   87.0
#
# [161280 rows x 4 columns]

# %% [markdown]
# Certaines données sont manquants. Remplissons ces données par interpollation polynomial (ordre 2) :

# %%
def interpolation(col, method, order = None):
    df_n230[col] = df_n230[col].astype(float)
    df_n230[col] = df_n230[col].interpolate(method = method, order = order)
    return df_n230[col]

# %%
for col in ['TV/h', 'speed']:
    df_n230[col] = interpolation(col,'polynomial', 2)

# %% [markdown]
# ## Ajout des données météo

# %%
weather_df = pd.read_csv('polynomial_weather.csv', sep = ',')

# %%
weather_df.index = weather_df['date']
df_n230.index = df_n230['date']
df_n230.drop(['date'], axis = 1, inplace = True)

# %%
df_n230 = df_n230.join(weather_df)

# %%
df_n230
# Out:
#                         sensor        TV/h      speed                 date  \
# date
# 2019-09-23 00:00:00  5442.00 2         NaN        NaN  2019-09-23 00:00:00
# 2019-09-23 00:00:00  5342.00 1  879.449197  88.348895  2019-09-23 00:00:00
# 2019-09-23 00:00:00  5042.00 1  510.000000  89.000000  2019-09-23 00:00:00
# 2019-09-23 00:00:00  5042.00 2  620.000000  87.000000  2019-09-23 00:00:00
# 2019-09-23 00:00:00  5742.00 1  529.384744  81.590626  2019-09-23 00:00:00
# ...                        ...         ...        ...                  ...
# 2019-10-20 23:54:00  5146.11 1  550.000000  71.000000  2019-10-20 23:54:00
# 2019-10-20 23:54:00  5146.10 2  110.000000  78.000000  2019-10-20 23:54:00
# 2019-10-20 23:54:00  5146.12 2  530.000000  83.000000  2019-10-20 23:54:00
# 2019-10-20 23:54:00   LAPI L41  970.000000  88.000000  2019-10-20 23:54:00
# 2019-10-20 23:54:00   LAPI L42  650.000000  87.000000  2019-10-20 23:54:00
#
#                      pression au niveau de la mer  \
# date
# 2019-09-23 00:00:00                      101790.0
# 2019-09-23 00:00:00                      101790.0
# 2019-09-23 00:00:00                      101790.0
# 2019-09-23 00:00:00                      101790.0
# 2019-09-23 00:00:00                      101790.0
# ...                                           ...
# 2019-10-20 23:54:00                      101484.0
# 2019-10-20 23:54:00                      101484.0
# 2019-10-20 23:54:00                      101484.0
# 2019-10-20 23:54:00                      101484.0
# 2019-10-20 23:54:00                      101484.0
#
#                      Variation de pression en 3 heures  \
# date
# 2019-09-23 00:00:00                          80.000000
# 2019-09-23 00:00:00                          80.000000
# 2019-09-23 00:00:00                          80.000000
# 2019-09-23 00:00:00                          80.000000
# 2019-09-23 00:00:00                          80.000000
# ...                                                ...
# 2019-10-20 23:54:00                         183.666667
# 2019-10-20 23:54:00                         183.666667
# 2019-10-20 23:54:00                         183.666667
# 2019-10-20 23:54:00                         183.666667
# 2019-10-20 23:54:00                         183.666667
#
#                      Vitesse du vent moyen 10 mn  Température  Point de rosée  \
# date
# 2019-09-23 00:00:00                     2.700000   287.950000      286.450000
# 2019-09-23 00:00:00                     2.700000   287.950000      286.450000
# 2019-09-23 00:00:00                     2.700000   287.950000      286.450000
# 2019-09-23 00:00:00                     2.700000   287.950000      286.450000
# 2019-09-23 00:00:00                     2.700000   287.950000      286.450000
# ...                                          ...          ...             ...
# 2019-10-20 23:54:00                     2.573333   283.573333      282.656667
# 2019-10-20 23:54:00                     2.573333   283.573333      282.656667
# 2019-10-20 23:54:00                     2.573333   283.573333      282.656667
# 2019-10-20 23:54:00                     2.573333   283.573333      282.656667
# 2019-10-20 23:54:00                     2.573333   283.573333      282.656667
#
#                      Visibilité horizontale  \
# date
# 2019-09-23 00:00:00                 17710.0
# 2019-09-23 00:00:00                 17710.0
# 2019-09-23 00:00:00                 17710.0
# 2019-09-23 00:00:00                 17710.0
# 2019-09-23 00:00:00                 17710.0
# ...                                     ...
# 2019-10-20 23:54:00                 47163.0
# 2019-10-20 23:54:00                 47163.0
# 2019-10-20 23:54:00                 47163.0
# 2019-10-20 23:54:00                 47163.0
# 2019-10-20 23:54:00                 47163.0
#
#                      Nébulosité des nuages de l'étage inférieur  \
# date
# 2019-09-23 00:00:00                                    8.000000
# 2019-09-23 00:00:00                                    8.000000
# 2019-09-23 00:00:00                                    8.000000
# 2019-09-23 00:00:00                                    8.000000
# 2019-09-23 00:00:00                                    8.000000
# ...                                                         ...
# 2019-10-20 23:54:00                                    4.133333
# 2019-10-20 23:54:00                                    4.133333
# 2019-10-20 23:54:00                                    4.133333
# 2019-10-20 23:54:00                                    4.133333
# 2019-10-20 23:54:00                                    4.133333
#
#                      Variation de pression en 24 heures  \
# date
# 2019-09-23 00:00:00                              1070.0
# 2019-09-23 00:00:00                              1070.0
# 2019-09-23 00:00:00                              1070.0
# 2019-09-23 00:00:00                              1070.0
# 2019-09-23 00:00:00                              1070.0
# ...                                                 ...
# 2019-10-20 23:54:00                              1181.0
# 2019-10-20 23:54:00                              1181.0
# 2019-10-20 23:54:00                              1181.0
# 2019-10-20 23:54:00                              1181.0
# 2019-10-20 23:54:00                              1181.0
#
#                      Température minimale du sol sur 12 heures  Etat du sol  \
# date
# 2019-09-23 00:00:00                                     286.45          1.0
# 2019-09-23 00:00:00                                     286.45          1.0
# 2019-09-23 00:00:00                                     286.45          1.0
# 2019-09-23 00:00:00                                     286.45          1.0
# 2019-09-23 00:00:00                                     286.45          1.0
# ...                                                        ...          ...
# 2019-10-20 23:54:00                                     282.79          1.0
# 2019-10-20 23:54:00                                     282.79          1.0
# 2019-10-20 23:54:00                                     282.79          1.0
# 2019-10-20 23:54:00                                     282.79          1.0
# 2019-10-20 23:54:00                                     282.79          1.0
#
#                      Hauteur de la neige fraiche  \
# date
# 2019-09-23 00:00:00                          0.0
# 2019-09-23 00:00:00                          0.0
# 2019-09-23 00:00:00                          0.0
# 2019-09-23 00:00:00                          0.0
# 2019-09-23 00:00:00                          0.0
# ...                                          ...
# 2019-10-20 23:54:00                          0.0
# 2019-10-20 23:54:00                          0.0
# 2019-10-20 23:54:00                          0.0
# 2019-10-20 23:54:00                          0.0
# 2019-10-20 23:54:00                          0.0
#
#                      Précipitation dans la dernière heure
# date
# 2019-09-23 00:00:00                                   0.0
# 2019-09-23 00:00:00                                   0.0
# 2019-09-23 00:00:00                                   0.0
# 2019-09-23 00:00:00                                   0.0
# 2019-09-23 00:00:00                                   0.0
# ...                                                   ...
# 2019-10-20 23:54:00                                   0.0
# 2019-10-20 23:54:00                                   0.0
# 2019-10-20 23:54:00                                   0.0
# 2019-10-20 23:54:00                                   0.0
# 2019-10-20 23:54:00                                   0.0
#
# [161280 rows x 16 columns]

# %% [markdown]
# ## Add-Datepart

# %%
df_n230['date'] = df_n230.index

# %%
df_n230['year'] = df_n230['date'].astype(str).apply(lambda x : x[:4])
df_n230['month'] = df_n230['date'].astype(str).apply(lambda x : x[5:7])
df_n230['day'] = df_n230['date'].astype(str).apply(lambda x : x[8:10])
df_n230['hour'] = df_n230['date'].astype(str).apply(lambda x : x[10:13])
df_n230['minutes'] = df_n230['date'].astype(str).apply(lambda x : x[14:16])

# %%
df_n230.to_csv('data/n230_clean_weather_selected', index = True)

# %%
df_n230 = pd.read_csv('data/n230_clean_weather_selected')
df_n230.index = df_n230['date']
df_n230.drop(['date'], axis = 1, inplace = True)

# %% [markdown]
# ## Création d'une carte avec les capteurs

# %%
df_sensors = pd.read_csv('data/Bordeaux_sensordef.csv', sep=';')

# %%
sensors_to_keep = df_n230['sensor'].value_counts().index.tolist()

# %%
dirty_idx = []
all_censors = df_sensors['sensor'].value_counts().index.tolist()
for sensor in all_censors:
    if sensor not in sensors_to_keep:
        df = df_sensors[df_sensors['sensor'] == sensor]
        for i in range(len(df)):
            dirty_idx.append(df.index[i])
print(len(dirty_idx))
# Out:
# 109

# %%
df_sensors = df_sensors[~df_sensors.index.isin(dirty_idx)]

# %%
df_sensors[['lat','lon']]
# Out:
#            lat       lon
# 53   44.820878 -0.518471
# 55   44.820933 -0.518100
# 59   44.826092 -0.509134
# 60   44.826134 -0.509315
# 61   44.835343 -0.499863
# 62   44.835014 -0.500026
# 68   44.848842 -0.503412
# 72   44.853130 -0.505016
# 73   44.853061 -0.505165
# 76   44.862905 -0.503809
# 78   44.867280 -0.503381
# 80   44.869317 -0.504325
# 81   44.868447 -0.504466
# 82   44.868490 -0.504654
# 83   44.868746 -0.504826
# 84   44.869779 -0.505518
# 88   44.877995 -0.509681
# 89   44.880111 -0.509828
# 90   44.883514 -0.510584
# 91   44.883925 -0.511477
# 92   44.884092 -0.512069
# 93   44.883251 -0.512496
# 131  44.815794 -0.520793
# 132  44.815794 -0.520626

# %%
dirty_idx = [131,55,60,61,72,83,81,78,80, 84,88,91,90,93]

# %%
df_carto = df_sensors[~df_sensors.index.isin(dirty_idx)]
df_carto = df_carto[['lat','lon']]

# %%
df_carto[['lat','lon']].to_csv('test_carte_gmaps.csv')

# %% [markdown]
# ## Ajout des variables de sorties

# %%
def etat_du_trafic(x):
    if x > 80: return 0
    else: return 1

# %%
df = pd.DataFrame(['test'] * 22, index = df_n230.columns.tolist() + ['speed6min']).T

# %%
capteurs = df_n230['sensor'].value_counts().index.tolist()
for capteur in capteurs:
    df_test = df_n230[df_n230['sensor'] == capteur]
    for period in [('30min',5),('60min', 10), ('3heures', 30), ('24heures', 240)]:
        var = "congestion+"+period[0]
        shift = period[1]   
        df_test[var] = df_test['speed'].shift(periods =-shift)
    df = pd.concat([df, df_test])
# Out:
# /opt/anaconda3/envs/fastai-cpu-v0.7/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
df.drop(['speed6min'], axis = 1, inplace = True)

# %%
df = df[~df.index.isin([0])]
df[df['sensor'] == capteurs[7]].head(35)
# Out:
#                         sensor        TV/h      speed               date.1  \
# 2019-09-23 00:00:00  5146.13 1  147.031444  55.467221  2019-09-23 00:00:00
# 2019-09-23 00:06:00  5146.13 1  154.884652  62.359201  2019-09-23 00:06:00
# 2019-09-23 00:12:00  5146.13 1       160.0       67.0  2019-09-23 00:12:00
# 2019-09-23 01:24:00      24             65.0             74.0
# 2019-09-23 01:30:00      30             62.0             75.0
# 2019-09-23 01:36:00      36             69.0             60.0
# 2019-09-23 01:42:00      42             63.0             64.0
# 2019-09-23 01:48:00      48             68.0             70.0
# 2019-09-23 01:54:00      54             74.0             68.0
# 2019-09-23 02:00:00       0             75.0             72.0
# 2019-09-23 02:06:00       6             60.0             72.0
# 2019-09-23 02:12:00      12             64.0             62.0
# 2019-09-23 02:18:00      18             70.0             61.0
# 2019-09-23 02:24:00      24             68.0             66.0
# 2019-09-23 02:30:00      30             72.0             65.0
# 2019-09-23 02:36:00      36             72.0             66.0
# 2019-09-23 02:42:00      42             62.0             70.0
# 2019-09-23 02:48:00      48             61.0             64.0
# 2019-09-23 02:54:00      54             66.0             67.0
# 2019-09-23 03:00:00       0             65.0             63.0
# 2019-09-23 03:06:00       6             66.0             66.0
# 2019-09-23 03:12:00      12             70.0             65.0
# 2019-09-23 03:18:00      18             64.0             63.0
# 2019-09-23 03:24:00      24             67.0             64.0
#
#                     congestion+3heures congestion+24heures
# 2019-09-23 00:00:00               72.0                68.0
# 2019-09-23 00:06:00               72.0                70.0
# 2019-09-23 00:12:00               62.0                70.0
# 2019-09-23 00:18:00               61.0                71.0
# 2019-09-23 00:24:00               66.0                70.0
# 2019-09-23 00:30:00               65.0                65.0
# 2019-09-23 00:36:00               66.0                72.0
# 2019-09-23 00:42:00               70.0                69.0
# 2019-09-23 00:48:00               64.0                68.0
# 2019-09-23 00:54:00               67.0                61.0
# 2019-09-23 01:00:00               63.0                62.0
# 2019-09-23 01:06:00               66.0                65.0
# 2019-09-23 01:12:00               65.0                65.0
# 2019-09-23 01:18:00               63.0                66.0
# 2019-09-23 01:24:00               64.0                67.0
# 2019-09-23 01:30:00               68.0                64.0
# 2019-09-23 01:36:00               71.0                67.0
# 2019-09-23 01:42:00               69.0                59.0
# 2019-09-23 01:48:00               70.0                68.0
# 2019-09-23 01:54:00               68.0                71.0
# 2019-09-23 02:00:00               70.0                61.0
# 2019-09-23 02:06:00               69.0                68.0
# 2019-09-23 02:12:00               69.0                56.0
# 2019-09-23 02:18:00               73.0                67.0
# 2019-09-23 02:24:00               70.0                63.0
# 2019-09-23 02:30:00               69.0                71.0
# 2019-09-23 02:36:00               71.0                70.0
# 2019-09-23 02:42:00               67.0                70.0
# 2019-09-23 02:48:00               71.0                63.0
# 2019-09-23 02:54:00               69.0                64.0
# 2019-09-23 03:00:00               68.0                70.0
# 2019-09-23 03:06:00               66.0                62.0
# 2019-09-23 03:12:00               67.0                65.0
# 2019-09-23 03:18:00               66.0                58.0
# 2019-09-23 03:24:00               67.0                64.0
#
# [35 rows x 25 columns]

# %%
df['date'] = df.index

# %%
trafic_datas = df[['date','sensor', 'congestion+30min', 'congestion+60min', 'congestion+3heures', 'congestion+24heures']]

# %%
df_sensors['id'] = df_sensors.index

# %%
df_to_join = df_sensors[['id', 'sensor']]
df_to_join.index = df_to_join['sensor']
df_to_join.drop(['sensor'], axis = 1, inplace = True)
# Out:
# /opt/anaconda3/envs/fastai-cpu-v0.7/lib/python3.7/site-packages/pandas/core/frame.py:4315: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
trafic_datas.index = trafic_datas['sensor']

# %%
trafic_datas = trafic_datas.join(df_to_join)

# %%
trafic_datas.index = trafic_datas['date']
trafic_datas.drop(['date'], axis=1, inplace = True)

# %%
trafic_datas.iloc[161030:].head(25)
# Out:
#                        sensor  congestion+30min  congestion+60min  \
# date
# 2019-10-19 23:00:00  LAPI L42              87.0              86.0
# 2019-10-19 23:06:00  LAPI L42              86.0              87.0
# 2019-10-19 23:12:00  LAPI L42              87.0              85.0
# 2019-10-19 23:18:00  LAPI L42              86.0              87.0
# 2019-10-19 23:24:00  LAPI L42              87.0              84.0
# 2019-10-19 23:30:00  LAPI L42              86.0              87.0
# 2019-10-19 23:36:00  LAPI L42              87.0              86.0
# 2019-10-19 23:42:00  LAPI L42              85.0              85.0
# 2019-10-19 23:48:00  LAPI L42              87.0              86.0
# 2019-10-19 23:54:00  LAPI L42              84.0              87.0
# 2019-10-20 00:00:00  LAPI L42              87.0              86.0
# 2019-10-20 00:06:00  LAPI L42              86.0              88.0
# 2019-10-20 00:12:00  LAPI L42              85.0              88.0
# 2019-10-20 00:18:00  LAPI L42              86.0              87.0
# 2019-10-20 00:24:00  LAPI L42              87.0              87.0
# 2019-10-20 00:30:00  LAPI L42              86.0              87.0
# 2019-10-20 00:36:00  LAPI L42              88.0              85.0
# 2019-10-20 00:42:00  LAPI L42              88.0              86.0
# 2019-10-20 00:48:00  LAPI L42              87.0              83.0
# 2019-10-20 00:54:00  LAPI L42              87.0              82.0
# 2019-10-20 01:00:00  LAPI L42              87.0              84.0
# 2019-10-20 01:06:00  LAPI L42              85.0              84.0
# 2019-10-20 01:12:00  LAPI L42              86.0              84.0
# 2019-10-20 01:18:00  LAPI L42              83.0              87.0
# 2019-10-20 01:24:00  LAPI L42              82.0              84.0
#
#                      congestion+3heures  congestion+24heures   id
# date
# 2019-10-19 23:00:00                84.0                 87.0  132
# 2019-10-19 23:06:00                84.0                 87.0  132
# 2019-10-19 23:12:00                84.0                 86.0  132
# 2019-10-19 23:18:00                87.0                 87.0  132
# 2019-10-19 23:24:00                84.0                 87.0  132
# 2019-10-19 23:30:00                85.0                 88.0  132
# 2019-10-19 23:36:00                84.0                 85.0  132
# 2019-10-19 23:42:00                84.0                 90.0  132
# 2019-10-19 23:48:00                86.0                 86.0  132
# 2019-10-19 23:54:00                87.0                 87.0  132
# 2019-10-20 00:00:00                86.0                  NaN  132
# 2019-10-20 00:06:00                87.0                  NaN  132
# 2019-10-20 00:12:00                85.0                  NaN  132
# 2019-10-20 00:18:00                83.0                  NaN  132
# 2019-10-20 00:24:00                87.0                  NaN  132
# 2019-10-20 00:30:00                82.0                  NaN  132
# 2019-10-20 00:36:00                85.0                  NaN  132
# 2019-10-20 00:42:00                81.0                  NaN  132
# 2019-10-20 00:48:00                81.0                  NaN  132
# 2019-10-20 00:54:00                85.0                  NaN  132
# 2019-10-20 01:00:00                86.0                  NaN  132
# 2019-10-20 01:06:00                87.0                  NaN  132
# 2019-10-20 01:12:00                83.0                  NaN  132
# 2019-10-20 01:18:00                84.0                  NaN  132
# 2019-10-20 01:24:00                85.0                  NaN  132

# %%
trafic_datas.tail()
# Out:
#                        sensor  congestion+30min  congestion+60min  \
# date
# 2019-10-20 23:30:00  LAPI L42               NaN               NaN
# 2019-10-20 23:36:00  LAPI L42               NaN               NaN
# 2019-10-20 23:42:00  LAPI L42               NaN               NaN
# 2019-10-20 23:48:00  LAPI L42               NaN               NaN
# 2019-10-20 23:54:00  LAPI L42               NaN               NaN
#
#                      congestion+3heures  congestion+24heures   id
# date
# 2019-10-20 23:30:00                 NaN                  NaN  132
# 2019-10-20 23:36:00                 NaN                  NaN  132
# 2019-10-20 23:42:00                 NaN                  NaN  132
# 2019-10-20 23:48:00                 NaN                  NaN  132
# 2019-10-20 23:54:00                 NaN                  NaN  132

# %%
trafic_datas['date'] = trafic_datas.index

# %%
trafic_datas_df_n230 = trafic_datas

# %%
trafic_datas.drop(['sensor'], axis = 1, inplace = True)

# %%
order_col = ['id', 'date', 'congestion+30min', 'congestion+60min', 'congestion+3heures', 'congestion+24heures']

# %%
trafic_datas.columns
# Out:
# Index(['congestion+30min', 'congestion+60min', 'congestion+3heures',
#        'congestion+24heures', 'id'],
#       dtype='object')

# %%
col_name = ['sensor_id', 'hour', 'trafic_30min', 'trafic_60min', 'trafic_3heures', 'trafic_24heures']
trafic_datas.columns = col_name
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-273-5f1c27b4fc61> in <module>
#       1 col_name = ['sensor_id', 'hour', 'trafic_30min', 'trafic_60min', 'trafic_3heures', 'trafic_24heures']
# ----> 2 trafic_datas.columns = col_name
#
# /opt/anaconda3/envs/fastai-cpu-v0.7/lib/python3.7/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5476         try:
#    5477             object.__getattribute__(self, name)
# -> 5478             return object.__setattr__(self, name, value)
#    5479         except AttributeError:
#    5480             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /opt/anaconda3/envs/fastai-cpu-v0.7/lib/python3.7/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     668     def _set_axis(self, axis: int, labels: Index) -> None:
#     669         labels = ensure_index(labels)
# --> 670         self._mgr.set_axis(axis, labels)
#     671         self._clear_item_cache()
#     672
#
# /opt/anaconda3/envs/fastai-cpu-v0.7/lib/python3.7/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     219         if new_len != old_len:
#     220             raise ValueError(
# --> 221                 f"Length mismatch: Expected axis has {old_len} elements, new "
#     222                 f"values have {new_len} elements"
#     223             )
#
# ValueError: Length mismatch: Expected axis has 5 elements, new values have 6 elements

# %%
def conversion_timestamp(x):
    return int(datetime.strptime(x, '%Y-%m-%d %H:%M:%S').strftime("%s")) + 7200

# On ajoute 7200 secondes (2 heures pour se caler sur le bon fuseau horaire)

# %%
trafic_datas['hour'] = trafic_datas['hour'].apply(lambda x : conversion_timestamp(x))
# Out:
# /opt/anaconda3/envs/fastai-cpu-v0.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
trafic_datas.to_csv('data/trafic_datas.csv', index = False)

# %% [markdown]
# ## Ajout des données du trafic

# %%
df_n230.head()
# Out:
#                         sensor        TV/h      speed               date.1  \
# date
# 2019-09-23 00:00:00  5442.00 2         NaN        NaN  2019-09-23 00:00:00
# 2019-09-23 00:00:00  5342.00 1  879.449197  88.348895  2019-09-23 00:00:00
# 2019-09-23 00:00:00  5042.00 1  510.000000  89.000000  2019-09-23 00:00:00
# 2019-09-23 00:00:00  5042.00 2  620.000000  87.000000  2019-09-23 00:00:00
# 2019-09-23 00:00:00  5742.00 1  529.384744  81.590626  2019-09-23 00:00:00
#
#                      pression au niveau de la mer  \
# date
# 2019-09-23 00:00:00                      101790.0
# 2019-09-23 00:00:00                      101790.0
# 2019-09-23 00:00:00                      101790.0
# 2019-09-23 00:00:00                      101790.0
# 2019-09-23 00:00:00                      101790.0
#
#                      Variation de pression en 3 heures  \
# date
# 2019-09-23 00:00:00                               80.0
# 2019-09-23 00:00:00                               80.0
# 2019-09-23 00:00:00                               80.0
# 2019-09-23 00:00:00                               80.0
# 2019-09-23 00:00:00                               80.0
#
#                      Vitesse du vent moyen 10 mn  Température  Point de rosée  \
# date
# 2019-09-23 00:00:00                          2.7       287.95          286.45
# 2019-09-23 00:00:00                          2.7       287.95          286.45
# 2019-09-23 00:00:00                          2.7       287.95          286.45
# 2019-09-23 00:00:00                          2.7       287.95          286.45
# 2019-09-23 00:00:00                          2.7       287.95          286.45
#
#                      Visibilité horizontale  ...  \
# date                                         ...
# 2019-09-23 00:00:00                 17710.0  ...
# 2019-09-23 00:00:00                 17710.0  ...
# 2019-09-23 00:00:00                 17710.0  ...
# 2019-09-23 00:00:00                 17710.0  ...
# 2019-09-23 00:00:00                 17710.0  ...
#
#                      Variation de pression en 24 heures  \
# date
# 2019-09-23 00:00:00                              1070.0
# 2019-09-23 00:00:00                              1070.0
# 2019-09-23 00:00:00                              1070.0
# 2019-09-23 00:00:00                              1070.0
# 2019-09-23 00:00:00                              1070.0
#
#                      Température minimale du sol sur 12 heures  Etat du sol  \
# date
# 2019-09-23 00:00:00                                     286.45          1.0
# 2019-09-23 00:00:00                                     286.45          1.0
# 2019-09-23 00:00:00                                     286.45          1.0
# 2019-09-23 00:00:00                                     286.45          1.0
# 2019-09-23 00:00:00                                     286.45          1.0
#
#                      Hauteur de la neige fraiche  \
# date
# 2019-09-23 00:00:00                          0.0
# 2019-09-23 00:00:00                          0.0
# 2019-09-23 00:00:00                          0.0
# 2019-09-23 00:00:00                          0.0
# 2019-09-23 00:00:00                          0.0
#
#                      Précipitation dans la dernière heure  year  month  day  \
# date
# 2019-09-23 00:00:00                                   0.0  2019      9   23
# 2019-09-23 00:00:00                                   0.0  2019      9   23
# 2019-09-23 00:00:00                                   0.0  2019      9   23
# 2019-09-23 00:00:00                                   0.0  2019      9   23
# 2019-09-23 00:00:00                                   0.0  2019      9   23
#
#                      hour  minutes
# date
# 2019-09-23 00:00:00     0        0
# 2019-09-23 00:00:00     0        0
# 2019-09-23 00:00:00     0        0
# 2019-09-23 00:00:00     0        0
# 2019-09-23 00:00:00     0        0
#
# [5 rows x 21 columns]

# %% [markdown]
# Création d'un nouvel indice afin de facilité la fusion des deux df.

# %%
df_n230['pour fusion'] = df_n230.index + ' ' + df_n230['sensor']
trafic_datas_df_n230['pour fusion'] = trafic_datas_df_n230.index + ' ' + trafic_datas_df_n230['sensor']

# %%
df_n230['date'] = df_n230.index
trafic_datas_df_n230['date'] = trafic_datas_df_n230.index

# %%
df_n230.index = df_n230['pour fusion']
trafic_datas_df_n230.index = trafic_datas_df_n230['pour fusion']

# %%
df_n230['pour fusion'].value_counts()
# Out:
# 2019-10-17 15:12:00 LAPI L41     1
# 2019-10-20 20:30:00 5044.10 2    1
# 2019-10-13 12:48:00 5146.13 1    1
# 2019-10-05 00:30:00 5742.00 2    1
# 2019-09-23 13:42:00 5146.10 2    1
#                                 ..
# 2019-10-04 01:00:00 5146.12 2    1
# 2019-10-05 10:42:00 5043.00 1    1
# 2019-09-25 15:48:00 5146.12 2    1
# 2019-10-09 20:54:00 5042.00 2    1
# 2019-09-26 08:30:00 5742.00 1    1
# Name: pour fusion, Length: 161280, dtype: int64

# %%
df_n230.drop(['pour fusion'], axis = 1, inplace = True)
trafic_datas_df_n230.drop(['pour fusion'], axis = 1, inplace = True)

# %%
trafic_datas.drop(['sensor', 'date'], axis = 1, inplace = True)

# %%
df_n230 = df_n230.join(trafic_datas_df_n230)

# %%
df_n230.index = df_n230['date']

# %%
df_n230.drop(['id'], axis = 1, inplace = True)

# %%
df_n230 = df_n230[1:]

# %%
df_n230.to_csv('data/df_n230_final.csv')
